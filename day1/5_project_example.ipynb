# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
data = pd.read_csv('../datas/word_test.csv')

# %%
data.head()
# Out:
#                                                 word
# 0  Python is an interpreted, high-level, general-...
# 1  Python is dynamically typed and garbage-collec...
# 2  Python was conceived in the late 1980s as a su...
# 3  The Python 2 language, i.e. Python 2.7.x, is "...
# 4  Python interpreters are available for many ope...

# %%
data.shape
# Out:
# (11, 1)

# %%
data_length = data['word'].apply(lambda x : len(x))
data_length
# Out:
# 0     373
# 1     265
# 2     706
# 3     341
# 4     297
# 5     807
# 6     143
# 7     350
# 8     309
# 9     251
# 10    395
# Name: word, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.hist(data_length, alpha = 0.5, color = 'r', label = 'word_length')
plt.title("word length histogram")
plt.xlabel("length of word")
plt.ylabel("number of word")
plt.show()

# %%
print("텍스트 길이 최대 값 : ", np.max(data_length))
print("텍스트 길이 최소 값 : ", np.min(data_length))
print("텍스트 길이 평균 값 : ", np.mean(data_length))
print("텍스트 길이 표준편차 값 : ", np.std(data_length))
print("텍스트 길이 중간 값 : ", np.median(data_length))
print("텍스트 길이 1사분위 값 : ", np.percentile(data_length, 25))
print("텍스트 길이 3사분위 값 : ", np.percentile(data_length, 75))
# Out:
# 텍스트 길이 최대 값 :  807
# 텍스트 길이 최소 값 :  143
# 텍스트 길이 평균 값 :  385.1818181818182
# 텍스트 길이 표준편차 값 :  188.04487771023665
# 텍스트 길이 중간 값 :  341.0
# 텍스트 길이 1사분위 값 :  281.0
# 텍스트 길이 3사분위 값 :  384.0

# %%
plt.figure(figsize=(12, 5))
plt.boxplot(data_length, labels = ['count'], showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ef04a20>,
#   <matplotlib.lines.Line2D at 0x12ef04d68>],
#  'caps': [<matplotlib.lines.Line2D at 0x12f0000f0>,
#   <matplotlib.lines.Line2D at 0x12f000438>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12ef04710>],
#  'medians': [<matplotlib.lines.Line2D at 0x12f000780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12f000dd8>],
#  'means': [<matplotlib.lines.Line2D at 0x12f000ac8>]}

# %%
cloud = WordCloud(width = 800, height = 600).generate(" ".join(data['word']))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)
